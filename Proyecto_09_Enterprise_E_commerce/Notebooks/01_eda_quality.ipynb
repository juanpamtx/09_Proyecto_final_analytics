# %%
# Tratamiento de datos

import pandas as pd
pd.set_option('display.max_columns', None)

# ----------

# Funciones personalizadas

import sys
import os

# Ruta absoluta al directorio raíz del proyecto
project_root = os.path.abspath(os.path.join(".."))

# Añadimos la ruta al path de Python
sys.path.append(project_root)


from src.utils import eda_utils as se

# %% [markdown]
# Realizamos un análisis de calidad de los datos. Vamos uno por uno

# %% [markdown]
# **1. Behavior**

# %%
behavior = pd.read_csv('../data/01_raw/behavior.csv')

# %%
se.eda_preliminar(behavior)
# Out:
#       customer_id  avg_session_time  pages_per_session  cart_abandon_rate  \
# 7368   CUST007369              1.04                 18               0.34
# 2701   CUST002702             19.74                  3               0.09
# 5243   CUST005244              5.78                  9               0.91
# 19977  CUST019978              2.41                  7               0.46
# 6190   CUST006191              5.43                  1               0.34
#
#        return_rate  support_tickets  review_score  behavior_churn_signal
# 7368          0.25                0          4.27                      0
# 2701          0.15                6          2.49                      0
# 5243          0.15                1          2.49                      0
# 19977         0.15                9          2.19                      1
# 6190          0.14                0          2.65                      0
# ---------------
# DIMENSIONES
# ...

# %% [markdown]
# **2. Customers**

# %%
customers = pd.read_csv('../data/01_raw/customers.csv')

# %%
se.eda_preliminar(customers)
# Out:
#       customer_id  age  gender country registration_date  loyalty_score  \
# 16880  CUST016881   33    Male  Brazil        2018-04-27          31.19
# 11662  CUST011663   65   Other  France        2019-09-29          12.96
# 16150  CUST016151   18    Male   India        2019-02-07          28.10
# 22094  CUST022095   35  Female  Canada        2019-07-27          10.28
# 6258   CUST006259   70   Other     USA        2019-09-27          46.81
#
#        lifetime_value  churn_label
# 16880         4752.34            0
# 11662         3894.30            0
# 16150          304.08            0
# 22094        17138.55            0
# 6258         19728.48            0
# ---------------
# DIMENSIONES
# Nuestro conjunto de datos presenta un total de 25000 filas y 8 columnas
# ---------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ...

# %% [markdown]
# **3. Products**

# %%
products = pd.read_csv('../data/01_raw/products.csv')

# %%
se.eda_preliminar(products)
# Out:
#      product_id        category   price  margin_percentage  popularity_score
# 774   PROD00775  Home & Kitchen  609.87              15.83             82.38
# 712   PROD00713          Beauty   84.01              30.60             18.74
# 479   PROD00480          Sports  706.16              12.06             67.34
# 1239  PROD01240     Electronics   83.54              20.50             26.10
# 1841  PROD01842          Beauty  461.07              23.50              3.44
# ---------------
# DIMENSIONES
# Nuestro conjunto de datos presenta un total de 2000 filas y 5 columnas
# ---------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         2000 non-null   object
#  1   category           2000 non-null   object
#  2   price              2000 non-null   float64
# ...

# %% [markdown]
# **4. Transactions**

# %%
transactions = pd.read_csv('../data/01_raw/transactions.csv')

# %%
se.eda_preliminar(transactions)
# Out:
#        transaction_id customer_id product_id  order_date  order_value  \
# 107372     TXN0107373  CUST002467  PROD01205  2022-09-09       215.28
# 73072      TXN0073073  CUST000697  PROD01487  2023-03-20       276.37
# 64792      TXN0064793  CUST002388  PROD01177  2021-04-10       561.39
# 53986      TXN0053987  CUST013359  PROD00944  2022-12-05        30.62
# 50026      TXN0050027  CUST016994  PROD00963  2023-01-11       427.89
#
#        payment_method device_type  discount_applied  shipping_delay_days  \
# 107372     Debit Card     Desktop              0.43                    6
# 73072          Crypto     Desktop              0.34                    8
# 64792          Crypto     Desktop              0.42                    7
# 53986          PayPal      Mobile              0.10                    5
# 50026     Credit Card      Tablet              0.16                    0
#
#         fraud_label
# 107372            0
# 73072             0
# 64792             0
# ...
